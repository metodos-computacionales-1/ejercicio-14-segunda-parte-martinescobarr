# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dat = np.loadtxt('rk4.dat')
t=dat[:,0]
x=dat[:,1]
v=dat[:,2]

# %%
plt.figure()
plt.plot(t,x,label='Posición')
plt.xlabel('t')
plt.ylabel('x')
plt.title("Posición")
plt.grid()
plt.legend()
plt.savefig('pos.png')

plt.figure()
plt.plot(x,v,label="x vs v")
plt.xlabel('x')
plt.ylabel('v')
plt.title("velocidad")
plt.grid()
plt.legend()
plt.savefig('vel.png')
